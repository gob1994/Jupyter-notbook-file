# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## ***（1）插入图片***

# %% [markdown]
# #### **方法1：markdown方法插入，但无法改变大小**

# %% [markdown]
# 语法格式
# ![title](abc.jpeg)

# %% [markdown]
# 插入效果
# ![title](abc.jpeg)

# %% [markdown]
# #### **方法2：使用html的img标签**

# %% [markdown]
# <img src='abc.jpeg' width=200px height=100px>

# %% [markdown]
# <img src='abc.jpeg' width=200px height=100px>

# %% [markdown]
# #### **方法3：使用IPython插件库中的Image功能**

# %%
from IPython.display import Image
Image(filename='abc.jpeg',width=200,height=200)

# %% [markdown]
# #### **方法4：使用%%html的魔法功能，注意语法**

# %%
# %%html
# <img src='abc.jpeg', width=200, height=200>
# Out:
# <img src='abc.jpeg', width=200, height=200>

# %% [markdown]
# ## ***（2）提示颜色***

# %% [markdown]
# class="alert alert-block alert-info">
# Tip: Use blue boxes (alert-info) for tips and notes.

# %%
pd.DataFrame
